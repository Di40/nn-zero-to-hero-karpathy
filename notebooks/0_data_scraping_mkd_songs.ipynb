# %%
# !pip install readability-lxml
# !pip install lxml_html_clean
# !pip install google-genai

# %%
from bs4 import BeautifulSoup
import urllib.request
from urllib.error import HTTPError, URLError
import re
import requests
from readability import Document
from google import genai
import time
import json
import urllib.parse

# %% [markdown]
# # Save/Read songs utils

# %%
def save_songs_to_json(songs, filename='mkd_songs.json'):
    with open(filename, 'w', encoding='utf-8') as json_file:
        json.dump(songs, json_file, indent=4, ensure_ascii=False)

def read_json_songs_to_list(filename='mkd_songs.json'):
    with open(filename, 'r', encoding='utf-8') as json_file:
        return json.load(json_file)

# %% [markdown]
# # Simple web mining

# %%
class SongScraperSimple:
  def __init__(self, urls):
    self.urls = urls  # List of URLs to scrape
    self.songs = []

  @staticmethod
  def _clean_text(text):
    '''
    Clean/Preprocess the text by:
    - Replacing non-breaking spaces (xa0) with regular spaces.
    - Adding spaces after punctuation symbols (.,!?) if missing.
    - Preserving line breaks for strophes.
    '''
    text = text.replace('\xa0', ' ')
    text = re.sub(r'([.?!])(?=\S)', r'\1 ', text)
    lines = [line.strip() for line in text.splitlines()]
    return '\n'.join(lines)

  def _add_song(self, text):
    self.songs.append(('\n'.join(text)).strip())

  def scrape_songs_from_url(self, url):
    '''
    Scrapes a URL to extract songs, where songs are separated by <h4> tags.
    '''
    try:
      html = urllib.request.urlopen(url)
      html_parse = BeautifulSoup(html, 'html.parser')

      current_song = []
      counter = 0
      for tag in html_parse.find_all(['h4', 'h3', 'p']):
        tag_text = tag.get_text()
        if tag.name == 'h4' or tag.name == 'h3':
          if current_song:  # Save the previously found song
            self._add_song(current_song)
            counter += 1
          current_song = [tag_text]  # Start a new song (add title)
        elif tag.name == "p" and current_song and tag_text.strip():  # Add paragraph to the current song
          current_song.append(self._clean_text(tag_text))
      if current_song:
        self._add_song(current_song)
        counter += 1
      print(f'Found {counter} songs.')

    except (HTTPError, URLError) as e:
      print(f"Failed to scrape URL {url}: {str(e)}")

  def scrape_all_songs(self):
    '''
    Scrape songs from all URLs in the list.
    '''
    for idx, url in enumerate(self.urls):
      print(f'Scraping URL #{idx+1}.')
      self.scrape_songs_from_url(url)

  def get_songs(self):
    '''
    Returns the list of scraped songs.
    '''
    return self.songs

# %%
mkd_songs_simple_urls = [
    # Beli mugri - Koco Racin
    'https://makedonskijazik.mk/2015/03/%D0%B1%D0%B5%D0%BB%D0%B8-%D0%BC%D1%83%D0%B3%D1%80%D0%B8-%D1%86%D0%B5%D0%BB%D0%B0%D1%82%D0%B0-%D1%81%D1%82%D0%B8%D1%85%D0%BE%D0%B7%D0%B1%D0%B8%D1%80%D0%BA%D0%B0.html',
    # Pesni - Konstantin Miladinov
    'https://makedonskijazik.mk/2015/04/%D0%BF%D0%B5%D1%81%D0%BD%D0%B8-%D0%BE%D0%B4-%D0%BA%D0%BE%D0%BD%D1%81%D1%82%D0%B0%D0%BD%D1%82%D0%B8%D0%BD-%D0%BC%D0%B8%D0%BB%D0%B0%D0%B4%D0%B8%D0%BD%D0%BE%D0%B2.html',
    # Oginot - Venko Markovski
    'https://makedonskijazik.mk/2015/04/%d0%be%d0%b3%d0%b8%d0%bd%d0%be%d1%82-%d0%be%d0%b4-%d0%b2%d0%b5%d0%bd%d0%ba%d0%be-%d0%bc%d0%b0%d1%80%d0%ba%d0%be%d0%b2%d1%81%d0%ba%d0%b8.html',
    # Krvava kosulja - Rajko Zinzifov:
    'https://makedonskijazik.mk/2015/04/%d0%ba%d1%80%d0%b2%d0%b0%d0%b2%d0%b0-%d0%ba%d0%be%d1%88%d1%83%d1%99%d0%b0-%d0%be%d0%b4-%d1%80%d0%b0%d1%98%d0%ba%d0%be-%d0%b6%d0%b8%d0%bd%d0%b7%d0%b8%d1%84%d0%be%d0%b2.html',
    ]

# %%
simple_song_scraper = SongScraperSimple(mkd_songs_simple_urls)
simple_song_scraper.scrape_all_songs()
songs = simple_song_scraper.get_songs()
print(f'Total {len(songs)} found.')
# Out:
# Scraping URL #1.
# Found 12 songs.
# Scraping URL #2.
# Found 15 songs.
# Scraping URL #3.
# Found 1 songs.
# Scraping URL #4.
# Found 1 songs.
# Total 29 found.

# %%
print(songs[0])
# Out:
# Денови
# Како на вратот ѓердани
# ниски камења студени,
# така на плешки денови
# легнале та натежнале
# Денови ли се — денови
# аргатски маки големи!
# Стани си утре порано
# дојди си вечер подоцна,
# наутро радост понеси
# навечер тага донеси —
# ај пуст да е, пуст да би
# останал живот кучешки!
# Роди се човек — роб биди
# роди се човек — скот умри
# скотски цел живот работи
# за други, туѓи имоти.
# За туѓи бели дворови,
# копај си црни гробови!
# За себе само ’ргај си
# за себе маки тргај си —
# нижи си ѓердан денови
# нижи си алки ковани,
# нижи си синџир железен
# околу вратот навезен!

# %%
# for song in songs:
#   print(song)
#   print(50*'-')

# %%
save_songs_to_json(songs, 'mkd_songs_1.json')

# %%
len(read_json_songs_to_list('mkd_songs_1.json'))
# Out:
# 29

# %% [markdown]
# Code works. But this class is very specific: we need the title to be in a \<h4> tag, and the strophes to follow it in \<p> tags. Let's try to use an LLM to help us with the processing.

# %% [markdown]
# # Web mining + LLM post processing

# %% [markdown]
# TODO: Try another model from the list bellow.
#
# (Free) Models with large context window:
# - 4k context:
#   - https://artificialanalysis.ai/models/llama-2-chat-13b
#   - https://artificialanalysis.ai/models/arctic-instruct
#   - https://artificialanalysis.ai/models/phi-3-mini
# - 1m context:
#   - https://artificialanalysis.ai/models/gemini-2-0-flash-experimental/providers
# - 2m context:
#   - https://artificialanalysis.ai/models/gemini-experimental-dec-2024

# %%
class SongExtractorLLM:
  def __init__(self, urls, model_id='gemini-2.0-flash-exp'):
    self.urls = urls
    self.client = genai.Client(api_key="AIzaSyA_aWKW9XMafspt_vZHeuTwbIg0waOY1wk")
    self.model_id = model_id
    self.songs_list = []

  def _scrape_text_from_url(self, url):
    try:
      session = requests.Session()
      session.max_redirects = 10

      response = session.get(url)
      response.raise_for_status()  # raise an exception for non-2xx status codes

      if response.status_code == 200:  # the request was successful
        doc = Document(response.content)
        title = doc.title()
        summary = doc.summary()

        # Use BeautifulSoup to parse the summary HTML and extract text
        soup = BeautifulSoup(summary, 'html.parser')
        text = soup.get_text(separator=' ', strip=True)

        return f"{title}\n{text}"
      else:
        print(f"\nFailed to fetch webpage. Status code: {response.status_code} for URL: {url}")
        return None

    except requests.RequestException as e:
      print(f"\nAn error occurred: {e}")
      return None

  def _call_llm_to_extract_songs(self, text):
    first_prompt = 'If there are songs in the following text in Macedonian, return me the song titles. If there are no songs, return an empty string:\n\n'
    song_titles = self.client.models.generate_content(model=self.model_id, contents=first_prompt+text).text.strip().split('\n')
    if not song_titles:
      return None
    print(f'Found {len(song_titles)} songs.')
    print('Extracting songs:')
    for idx, song_title in enumerate(song_titles):
      print(f'{idx+1}. {song_title}')
      time.sleep(1.5)
      second_prompt = f'If the song {song_title}, exists in {text} return me the whole song. If it does not, return an empty string:\n\n'
      song_content = self.client.models.generate_content(model='gemini-2.0-flash-exp', contents=second_prompt).text.strip()
      if song_content:
        self.songs_list.append(song_content)

  def _extract_songs_from_url(self, url):
    '''
    Extracts songs from the URL by scraping the text and calling the LLM.
    '''
    html_text = self._scrape_text_from_url(url)
    print('Scraping and parsing HTML done.')
    if html_text:
      self._call_llm_to_extract_songs(html_text)


  def extract_songs_from_all_urls(self):
    sleep_interval = 10
    total_urls = len(self.urls)
    for idx, url in enumerate(self.urls):
      print(50*'-')
      print(f"Processing URL #{idx+1}...")
      self._extract_songs_from_url(url)
      if idx <= total_urls - 2:
        print(f'Sleeping for {sleep_interval} seconds...')
        time.sleep(sleep_interval)
        print('Continuing.')

  def get_songs(self):
    '''
    Returns the list of scraped songs.
    '''
    return self.songs_list

# %%
mkd_songs_complex_urls = [
    # Izbor pesni - Kole Nedelkovski
     'https://makedonskijazik.mk/2011/03/%d0%b8%d0%b7%d0%b1%d0%be%d1%80-%d0%bf%d0%b5%d1%81%d0%bd%d0%b8-%d0%be%d0%b4-%d0%ba%d0%be%d0%bb%d0%b5-%d0%bd%d0%b5%d0%b4%d0%b5%d0%bb%d0%ba%d0%be%d0%b2%d1%81%d0%ba%d0%b8.html',
    # Makedonski narodni pesni
    'https://makedonskijazik.mk/2009/10/%d0%bc%d0%b0%d0%ba%d0%b5%d0%b4%d0%be%d0%bd%d1%81%d0%ba%d0%b8-%d0%bd%d0%b0%d1%80%d0%be%d0%b4%d0%bd%d0%b8-%d0%bf%d0%b5%d1%81%d0%bd%d0%b8.html'
    ]

# %%
llm_song_extractor = SongExtractorLLM(mkd_songs_complex_urls)
llm_song_extractor.extract_songs_from_all_urls()
songs = llm_song_extractor.get_songs()
print(f'Found {len(songs)} songs.')
# Out:
# --------------------------------------------------
# Processing URL #1...
# Scraping and parsing HTML done.
# Found 6 songs.
# Extracting songs:
# 1. Стојан на Ордановци
# 2. Раткина неволја
# 3. На кинисување
# 4. Скитник
# 5. Причинуење
# 6. Пеш по светот
# Sleeping for 10 seconds...
# Continuing.
# --------------------------------------------------
# Processing URL #2...
# Scraping and parsing HTML done.
# Found 10 songs.
# Extracting songs:
# 1. Нели ти стига
# 2. Ајде дали знаеш паметиш Милице
# 3. На Струга дуќан да имам
# 4. Распукала Шар Планина
# 5. Зајко младоженец
# 6. Учи ме мајко, карај ме
# 7. Марко Крале ја одменува свадбарината
# 8. Болен Дојчин
# 9. Болен ми лежи Миле Поп Орданов
# 10. Слушам кај шумат шумите
# Found 16 songs.

# %%
# for song in songs:
#   print(50*"-")
#   print(song)

# %%
save_songs_to_json(songs, 'mkd_songs_2.json')

# %%
len(read_json_songs_to_list('mkd_songs_2.json'))
# Out:
# 16

# %% [markdown]
# # Wiki Web mining

# %%
main_url = "https://mk.wikisource.org/wiki/%D0%9C%D0%B0%D0%BA%D0%B5%D0%B4%D0%BE%D0%BD%D1%81%D0%BA%D0%B8_%D0%BD%D0%B0%D1%80%D0%BE%D0%B4%D0%BD%D0%B8_%D0%BF%D0%B5%D1%81%D0%BD%D0%B8"

response = requests.get(main_url)
soup = BeautifulSoup(response.content, 'html.parser')

song_links = soup.find_all('a', href=True)
song_urls = [link['href'] for link in song_links if '/wiki/' in link['href']]

song_urls = [song_url for song_url in song_urls if song_url.startswith('/wiki/')]
song_urls = song_urls[27:-4]

# %%
song_urls_decoded = [urllib.parse.unquote(url) for url in song_urls]
song_urls_decoded
# Out:
# ['/wiki/Абер_дојде_Донке',
#  '/wiki/Абер_иде_од_Могила',
#  '/wiki/Ај_да_бегаме_мори_Васе',
#  '/wiki/Ај_засвирете_ми_чалгии',
#  '/wiki/Ај_што_ми_е_мило_ем_драго',
#  '/wiki/Ај!_В_Македонија_глас_се_чует',
#  '/wiki/Ајде_дали_знаеш_паметиш_Милице',
#  '/wiki/Ајде_жалај_ме,_Малино',
#  '/wiki/Ајде_Милке_да_бегаме',
#  '/wiki/Ајде_мори_Стојно_ле,_мој_соколе',
#  '/wiki/Ајде_поминувам_заминувам',
#  '/wiki/Ајде_слушај,_слушај,_Калеш_бре_Анѓо',
#  '/wiki/Ајде_ќе_те_прашам_бре_Донке',
#  '/wiki/Ајде_шана_мана_на_кантарот',
#  '/wiki/Ајде_што_пијана_шеташ_Фиме',
#  '/wiki/Ајде_што_ти_текна',
#  '/wiki/Ајде,_брала_мома_бело_ми_грозје,_ем_црно',
#  '/wiki/Ајде,_ред_се_редат,_мале',
#  '/wiki/Ако_пијам_рујно_вино',
#  '/wiki/Ако_умрам_ил_загинам',
#  '/wiki/Ангелино_моме',
#  '/wiki/Антице_жална_душице',
#  '/wiki/Ах_љубов,_пак_љубов',
#  '/wiki/Бело_лице_љубам_јас',
#  '/wiki/Билбил_пее_во_планина',
#  '/wiki/Билјана_платно_белеше',
#  '/wiki/Битола,_мој_роден_крај',
#  '/wiki/Бог_да_бие_мојта_мајка',
#  '/wiki/Бог_да_бие_Русе_твојта_мајка',
#  '/wiki/Бог_да_го_убие_мамо',
#  '/wiki/Болен_Дојчин',
#  '/wiki/Болен_лежи_катил_Ѓорѓи',
#  '/wiki/Болен_лежи_Миле_Поп_Јорданов',
#  '/wiki/Болен_лежи_млад_Стојан',
#  '/wiki/Бор_садила_мома_Евгенија',
#  '/wiki/Брала_мома_капини',
#  '/wiki/Буките_развиват',
#  '/wiki/Великина',
#  '/wiki/Виена_лоза_виена',
#  '/wiki/Вино_пијам,_ем_ракија',
#  '/wiki/Во_влашкото_маало_жолти_куќи_високи',
#  '/wiki/Врана_коња_јавам_јас',
#  '/wiki/Гледај_ме,_гледај_либе',
#  '/wiki/Го_фатиле_клети_Турци_едно_моме',
#  '/wiki/Градел_Илија_манастир',
#  '/wiki/Гукни_ми_гукни_гугутко',
#  '/wiki/Да_ти_пукне_мила_мајко_најмилото',
#  '/wiki/Давај_ме_мила_мамо,_давај_ме',
#  '/wiki/Дали_думаш_либе',
#  '/wiki/Дафино_вино_црвено',
#  '/wiki/Две_невесте_тикве_брале',
#  '/wiki/Девет_години',
#  '/wiki/Дејгиди_луди_млади_години',
#  '/wiki/Дека_се_чуло_и_видело',
#  '/wiki/Димна_Јуда_град_градила',
#  '/wiki/Димчета_аскер_го_писале',
#  '/wiki/До_кога_браќа_мили_Македонци',
#  '/wiki/Дојди,_дојди_калеш_море_Димчо',
#  '/wiki/Дојди,_дојди_малој_моме',
#  '/wiki/Дојчин_јунак,_Сирак_Јанко_и_Крали_Марко,_Солунски_чувачи',
#  '/wiki/Дотекла_вода_студена',
#  '/wiki/Драганка_ѓергеф_везеше',
#  '/wiki/Дремка_ми_се_дреме_мила_мамо',
#  '/wiki/Ѓорушице_црно_око',
#  '/wiki/Ѓул_трендафил',
#  '/wiki/Ѓурѓово_лето_проклето',
#  '/wiki/Една_вечер',
#  '/wiki/Една_мома_љубам_јас',
#  "/wiki/Една_мома_с'мајка_е",
#  '/wiki/Едно_време_си_бев_ерген',
#  '/wiki/Едно_мало_моме',
#  '/wiki/Еј_море_девојче',
#  '/wiki/Еј_ти_моме,_мало_моме',
#  '/wiki/Елено_моме,_Елено',
#  '/wiki/Елено_ќерко,_Елено',
#  '/wiki/Елено_ќерко',
#  '/wiki/Ерген_одев_мамо',
#  '/wiki/Жени_ме_мамо,_жени_ме',
#  '/wiki/За_кого_ти_цути_Дано,_лицето',
#  '/wiki/Зајди,_зајди_јасно_сонце',
#  '/wiki/Зајко_кокорајко',
#  '/wiki/Заплакало_е_Мариово',
#  '/wiki/Засвирил_Стојан',
#  '/wiki/Заспала_Јанка,_Јанинка',
#  '/wiki/Збогом_мајко_јас_отидов',
#  '/wiki/Земјо_Македонска',
#  '/wiki/Зошто_си_ме_мајко_родила',
#  '/wiki/Зурли_трештат_на_сред_село',
#  '/wiki/И_ние_сме_деца_на_Македонија',
#  '/wiki/И_таму_е_мојата_родина',
#  '/wiki/Извикна_Јана_провикна',
#  '/wiki/Излегов_да_се_прошетам',
#  '/wiki/Излегол_Јане_прошетал',
#  '/wiki/Илчовице,_млада_невесто',
#  '/wiki/Имала_мајка_до_девет_сина',
#  '/wiki/Ја_излези_стара_мајко',
#  '/wiki/Јана_мајка_љуто_колни',
#  '/wiki/Јано_Јанке_Кумановке',
#  '/wiki/Јано_мори,_Јано_леле,_севдалино',
#  '/wiki/Јас_Методи_Патче_од_Охрида',
#  '/wiki/Јас_сум_мома_Охриѓанка',
#  '/wiki/Јас_те_пратив_на_вода_Калино',
#  '/wiki/Јовано,_Јованке',
#  '/wiki/Каде_се_чуло_видело',
#  '/wiki/Каде_се_чуло_мамо_видело',
#  '/wiki/Каде_си_тргнала_Кито',
#  '/wiki/Кажи_Јано,_кажи_душо',
#  '/wiki/Кажи_ми,_кажи_Катинке',
#  '/wiki/Кажи_Рајне,_кажи_душо',
#  '/wiki/Кажи,_кажи_либе_Стано',
#  '/wiki/Како_што_е_таа_чаша_полна_со_вино',
#  '/wiki/Калеш_Дончо',
#  '/wiki/Каљо,_Калино_девојче',
#  '/wiki/Кандисал_Ајрудин_паша',
#  '/wiki/Кандисуј_бре,_лудо_младо',
#  '/wiki/Каранфил_невесто_мори',
#  '/wiki/Кате,_Кате_лично_моме',
#  '/wiki/Кате,_лично_девојче',
#  '/wiki/Кирајџиче,_јабанџиче',
#  '/wiki/Кито_моме,_Кито_душо',
#  '/wiki/Кога_војници_тргнавме',
#  '/wiki/Кога_се_мажеше_што_ти_се_чинеше',
#  '/wiki/Кога_си_тргнав_в_туѓина',
#  '/wiki/Кога_ќе_одиш_моме_за_вода',
#  '/wiki/Кој_што_ме_чуе_да_пеам',
#  '/wiki/Крај_Вардарот_седеше',
#  '/wiki/Кранфило,_фил-фило_моме',
#  '/wiki/Крушево_абер_пристигна',
#  '/wiki/Кумановско_поље',
#  '/wiki/Кучињата_лаат,_пазарџии_идат',
#  '/wiki/Лажи,_лажи_Вере',
#  '/wiki/Леле_мајко_што_ме_роди',
#  '/wiki/Ленка_пиши_бела_книга',
#  '/wiki/Ленче_болно_лежи',
#  '/wiki/Ленче_бре_душо',
#  '/wiki/Ленче_бре_душо,_Ленче_бре_срце',
#  '/wiki/Лешочкиот_манастир',
#  '/wiki/Лилјано_моме_убаво',
#  '/wiki/Лилјано_моме,_Лилјано',
#  '/wiki/Лино,_мори_моме,_севдалино',
#  '/wiki/Лисаво',
#  '/wiki/Лулела_е_Јана',
#  '/wiki/Љубеле_се_двајца_млади',
#  '/wiki/Љуби,_љуби_лудо_младо',
#  '/wiki/Магдо_мори,_Магдалено',
#  '/wiki/Мајка_на_Марика_думаше',
#  '/wiki/Македонско_девојче',
#  '/wiki/Малихери_пукаја',
#  '/wiki/Мамо,_кој_чука_на_порти',
#  '/wiki/Мара_Охриѓанка',
#  '/wiki/Марие_млада_невесто',
#  '/wiki/Марие,_дилбер_бела,_Марие',
#  '/wiki/Марика_мома_убава',
#  '/wiki/Мариче_ле,_лично,_девојче',
#  '/wiki/Марко_коси_зелена_ливада',
#  '/wiki/Марко_чека_месец_да_огрее',
#  '/wiki/Маце_маце_тече_вода_студена',
#  '/wiki/Ми_го_затвориле_младиот_Јорданчо',
#  '/wiki/Ми_заплакало_селото,_селото_Ваташа',
#  '/wiki/Ми_товарил_калеш_Дончо',
#  '/wiki/Мила_мајко_мојто_либе_не_ми_е_дома',
#  '/wiki/Мила_мајко_што_ме_роди_толку_сиромав',
#  '/wiki/Мирјано_мори,_Мирјано',
#  '/wiki/Многу_крвја,_многу_солзи',
#  '/wiki/Мома_уф_зандана',
#  '/wiki/Мома_седи_на_пенџерe',
#  '/wiki/Море_кога_одев_мила_мамо',
#  '/wiki/Море_сокол_пие',
#  '/wiki/Море_три_години_Стамбол_го_шетав',
#  '/wiki/Мори_моме_Магде',
#  '/wiki/Мори_чупи_Костурчанки',
#  '/wiki/На_лево_оро',
#  '/wiki/На_Струга_дуќан_да_имам',
#  '/wiki/На_срце_ми_лежи,_мила_мамо',
#  '/wiki/На_сред_село_тапан_чука',
#  '/wiki/Народе_Македонски',
#  '/wiki/Не_кажувај_либе_добра_ноќ',
#  '/wiki/Не_прибирај_мила_мамо_стројници',
#  '/wiki/Не_плачи_мило_либе,_не_жали_(Параходот)',
#  '/wiki/Не_раѓај_мајко,_лична_Македонијо',
#  '/wiki/Не_се_бели_Маре_мори',
#  '/wiki/Не_се_кревај_на_големо',
#  '/wiki/Не_се_фаќај_Доне_Донке_до_мене',
#  '/wiki/Не_си_го_продавај_Кољо_чифликот',
#  '/wiki/Нели_сторивме_вера_и_клетва',
#  '/wiki/Нели_ти_реков,_моме_Донке',
#  '/wiki/Нели_ти_реков,_не_оди_боса',
#  '/wiki/Немој_ме,_мила_мамо,_луто_да_колниш',
#  '/wiki/Нешо_пиле,_Нешо_мори,_мамино_калешо',
#  '/wiki/Низ_двори_се_шета_мома_Катерина',
#  '/wiki/Никнало,_никнало,_цвеќе_шарено',
#  '/wiki/Нико,_Нико_мори,_меанџико',
#  '/wiki/Облак_се_вие,_орлите_пиштат',
#  '/wiki/Оган_го_гори_Брезово',
#  '/wiki/Огрејала_еј_месечина',
#  '/wiki/Огрејала_јасна_ѕвезда',
#  '/wiki/Од_Битола_до_Вевчани,_си_сардисано',
#  '/wiki/Од_поле_идат_бабо_сејмени',
#  '/wiki/Од_умот_се_подизгубив',
#  '/wiki/Одздола_иде_мале',
#  '/wiki/Ожени_ме_мамо,_женет_да_одам',
#  '/wiki/Ојде_дедо_во_градина',
#  '/wiki/Ој_Недо,_Недо,_земи_ме_Недо',
#  '/wiki/Ој,_Јано,_Јано,_убава_Јано',
#  '/wiki/Ој,_ти_моме_лудо_ли_си',
#  '/wiki/Ој,_ти_пиле,_славеј_пиле',
#  '/wiki/Ората_копата',
#  '/wiki/Оре_моме_седмојанче',
#  '/wiki/Ордан_седи_на_кулата',
#  '/wiki/Останала,_останала_жена_удовица',
#  '/wiki/Отвори_Лено_вратничка',
#  '/wiki/Не_плачи_мило_либе,_не_жали_(Параходот)',
#  '/wiki/Песна_ви_пеам_Македонци',
#  '/wiki/Песна_за_Деспина',
#  '/wiki/Песна_за_Крушевската_република',
#  '/wiki/Песна_за_Христо_Узунов',
#  '/wiki/Петлите_пеат,_зората_се_зори',
#  '/wiki/Пилето_ми_пее_рано_на_сабајле',
#  '/wiki/Писмо_дојде_од_Солуна_града',
#  '/wiki/По_друм_одам_мајче',
#  '/wiki/Подигни_си,_бре_невесте_дулачето',
#  '/wiki/Подранила_Цена_за_вода_студена',
#  '/wiki/Појде_моме_на_вода',
#  '/wiki/Поминаа_луди_млади_години',
#  '/wiki/Послушајте_патриоти',
#  '/wiki/Развила_гора_зелена',
#  '/wiki/Разграни_гранка_маслинка',
#  '/wiki/Рајна_на_пенџере_седеше',
#  '/wiki/Рајна_на_порти_стоеше',
#  '/wiki/Распукала_Шар_Планина',
#  '/wiki/Са_ноќ_ми_билбил_препеа',
#  '/wiki/Саде_ти_се_чудам,_Цвето',
#  '/wiki/Само_ме_гледаш,_очи_ми_пиеш',
#  '/wiki/Свалил_се_млад_Димитар_од_Разловци',
#  '/wiki/Се_заљубив_во_девојче_убаво',
#  '/wiki/Се_запали_пиле_Трено_одајчето',
#  '/wiki/Секој_што_мине_помине',
#  '/wiki/Сестра_моли_брата_за_вечера',
#  '/wiki/Си_заљубив_едно_моме',
#  '/wiki/Сите_девојчиња,_мамо,_се_мажија',
#  '/wiki/Славеј_пиле_рано_пее',
#  '/wiki/Слегло_моме_во_градина',
#  '/wiki/Слушам_кај_шумат_шумите',
#  '/wiki/Сношти_минав_покрај_вази',
#  '/wiki/Сношти_си_мамо_поминав',
#  '/wiki/Собрале_ми_се_набрале',
#  '/wiki/Собрале_ми_се_набрале_нашите_лични_ергени',
#  '/wiki/Сокол_ми_лета_високо',
#  '/wiki/Срце_ме_боли_ќе_умрам',
#  '/wiki/Стани_запали_Тинке_борина',
#  '/wiki/Стани_моме_да_заиграш',
#  '/wiki/Сторил_ниет_Зајко',
#  '/wiki/Сулиман_ага',
#  '/wiki/Та_ти_ле_се_најде_бабо',
#  '/wiki/Таму_долу_Криволачко,_Црвени_Брегови',
#  '/wiki/Те_видов_тебе_и_се_заљубив',
#  '/wiki/Те_сакам_песно_македонска',
#  '/wiki/Тешка_беше_нашата_разделба',
#  '/wiki/Тинка_иди_од_Битола',
#  '/wiki/Трба_трби_Гевгелија',
#  '/wiki/Тргнала_ми_мома_Рума',
#  '/wiki/Три_години_либе_ние_се_сакавме',
#  '/wiki/Туѓината_пуста_да_остане',
#  '/wiki/Туљо_бре,_туљо_Салтано',
#  '/wiki/У_ливаду_потке_наше_моме_кротке',
#  '/wiki/Учи_ме_мајко_карај_ме',
#  '/wiki/Фанче_ојде_во_Калишта',
#  '/wiki/Фатила_зима',
#  '/wiki/Фато_мори_душманке',
#  '/wiki/Црна_се_чума_зададе',
#  '/wiki/Црно_му_било_пишано_на_Александро_Турунџев',
#  '/wiki/Четворица_комити',
#  '/wiki/Што_имала_к’смет_Стамена',
#  '/wiki/Што_се_срамиш_калеш_Кирчо']

# %%
songs = []
base_url = "https://mk.wikisource.org"

for song_url in song_urls:
  full_url = base_url + song_url
  response = requests.get(full_url)
  soup = BeautifulSoup(response.content, 'html.parser')

  song_div = soup.find('div', {'class': 'mw-content-ltr mw-parser-output'})

  # <dl> and <dd> tags
  if song_div:
    song_lyrics = []
    title = urllib.parse.unquote(song_url[6:].replace('_', ' '))

    for dl in song_div.find_all('dl'):
      for dd in dl.find_all('dd'):
        song_lyrics.append(dd.get_text())

    if song_lyrics:
      song_title_lyrics = title + '\n' + '\n'.join(song_lyrics)
      songs.append(song_title_lyrics)
      print(title)
# Out:
# Абер дојде Донке
# Абер иде од Могила
# Ај да бегаме мори Васе
# Ај засвирете ми чалгии
# Ај што ми е мило ем драго
# Ај! В Македонија глас се чует
# Ајде дали знаеш паметиш Милице
# Ајде жалај ме, Малино
# Ајде Милке да бегаме
# Ајде мори Стојно ле, мој соколе
# Ајде поминувам заминувам
# Ајде слушај, слушај, Калеш бре Анѓо
# Ајде ќе те прашам бре Донке
# Ајде шана мана на кантарот
# Ајде што пијана шеташ Фиме
# Ајде што ти текна
# Ајде, ред се редат, мале
# Ако пијам рујно вино
# Ако умрам ил загинам
# Ангелино моме
# Антице жална душице
# Ах љубов, пак љубов
# Бело лице љубам јас
# Билбил пее во планина
# Билјана платно белеше
# Битола, мој роден крај
# Бог да бие мојта мајка
# Бог да бие Русе твојта мајка
# Бог да го убие мамо
# Болен лежи катил Ѓорѓи
# Болен лежи Миле Поп Јорданов
# Болен лежи млад Стојан
# Бор садила мома Евгенија
# Брала мома капини
# Буките развиват
# Великина
# Виена лоза виена
# Вино пијам, ем ракија
# Во влашкото маало жолти куќи високи
# Врана коња јавам јас
# Гледај ме, гледај либе
# Го фатиле клети Турци едно моме
# Градел Илија манастир
# Гукни ми гукни гугутко
# Да ти пукне мила мајко најмилото
# Давај ме мила мамо, давај ме
# Дали думаш либе
# Дафино вино црвено
# Две невесте тикве брале
# Девет години
# Дејгиди луди млади години
# Дека се чуло и видело
# Димна Јуда град градила
# Димчета аскер го писале
# До кога браќа мили Македонци
# Дојди, дојди калеш море Димчо
# Дојди, дојди малој моме
# Дотекла вода студена
# Драганка ѓергеф везеше
# Дремка ми се дреме мила мамо
# Една вечер
# Една мома љубам јас
# Една мома с'мајка е
# Едно време си бев ерген
# Едно мало моме
# Еј море девојче
# Еј ти моме, мало моме
# Елено моме, Елено
# Елено ќерко, Елено
# Елено ќерко
# Ерген одев мамо
# Жени ме мамо, жени ме
# За кого ти цути Дано, лицето
# Зајди, зајди јасно сонце
# Зајко кокорајко
# Заплакало е Мариово
# Заспала Јанка, Јанинка
# Збогом мајко јас отидов
# Земјо Македонска
# Зошто си ме мајко родила
# Зурли трештат на сред село
# И ние сме деца на Македонија
# И таму е мојата родина
# Извикна Јана провикна
# Излегов да се прошетам
# Излегол Јане прошетал
# Илчовице, млада невесто
# Имала мајка до девет сина
# Јовано, Јованке
# Каде се чуло видело
# Каде се чуло мамо видело
# Каде си тргнала Кито
# Кажи Јано, кажи душо
# Кажи ми, кажи Катинке
# Кажи Рајне, кажи душо
# Кажи, кажи либе Стано
# Како што е таа чаша полна со вино
# Калеш Дончо
# Каљо, Калино девојче
# Кандисал Ајрудин паша
# Кандисуј бре, лудо младо
# Каранфил невесто мори
# Кате, Кате лично моме
# Кате, лично девојче
# Кирајџиче, јабанџиче
# Кито моме, Кито душо
# Кога војници тргнавме
# Кога се мажеше што ти се чинеше
# Кога си тргнав в туѓина
# Кога ќе одиш моме за вода
# Кој што ме чуе да пеам
# Крај Вардарот седеше
# Кранфило, фил-фило моме
# Крушево абер пристигна
# Кумановско поље
# Кучињата лаат, пазарџии идат
# Лажи, лажи Вере
# Леле мајко што ме роди
# Ленка пиши бела книга
# Ленче болно лежи
# Ленче бре душо
# Ленче бре душо, Ленче бре срце
# Лешочкиот манастир
# Лилјано моме убаво
# Лилјано моме, Лилјано
# Лино, мори моме, севдалино
# Лисаво
# Лулела е Јана
# Магдо мори, Магдалено
# Мајка на Марика думаше
# Малихери пукаја
# Мамо, кој чука на порти
# Мара Охриѓанка
# Марие млада невесто
# Марие, дилбер бела, Марие
# Марика мома убава
# Мариче ле, лично, девојче
# Марко коси зелена ливада
# Марко чека месец да огрее
# Маце маце тече вода студена
# Ми го затвориле младиот Јорданчо
# Ми заплакало селото, селото Ваташа
# Ми товарил калеш Дончо
# Мила мајко мојто либе не ми е дома
# Мила мајко што ме роди толку сиромав
# Мирјано мори, Мирјано
# Многу крвја, многу солзи
# Мома уф зандана
# Море кога одев мила мамо
# Море сокол пие
# Море три години Стамбол го шетав
# Мори моме Магде
# Мори чупи Костурчанки
# На лево оро
# На Струга дуќан да имам
# На срце ми лежи, мила мамо
# На сред село тапан чука
# Народе Македонски
# Не кажувај либе добра ноќ
# Не прибирај мила мамо стројници
# Не плачи мило либе, не жали (Параходот)
# Не раѓај мајко, лична Македонијо
# Не се бели Маре мори
# Не се кревај на големо
# Не се фаќај Доне Донке до мене
# Не си го продавај Кољо чифликот
# Нели сторивме вера и клетва
# Нели ти реков, моме Донке
# Нели ти реков, не оди боса
# Немој ме, мила мамо, луто да колниш
# Нешо пиле, Нешо мори, мамино калешо
# Низ двори се шета мома Катерина
# Никнало, никнало, цвеќе шарено
# Нико, Нико мори, меанџико
# Оган го гори Брезово
# Огрејала еј месечина
# Огрејала јасна ѕвезда
# Од Битола до Вевчани, си сардисано
# Од поле идат бабо сејмени
# Од умот се подизгубив
# Одздола иде мале
# Ожени ме мамо, женет да одам
# Ојде дедо во градина
# Ој Недо, Недо, земи ме Недо
# Ој, Јано, Јано, убава Јано
# Ој, ти моме лудо ли си
# Ој, ти пиле, славеј пиле
# Ората копата
# Оре моме седмојанче
# Ордан седи на кулата
# Останала, останала жена удовица
# Отвори Лено вратничка
# Не плачи мило либе, не жали (Параходот)
# Песна ви пеам Македонци
# Песна за Деспина
# Песна за Крушевската република
# Песна за Христо Узунов
# Петлите пеат, зората се зори
# Пилето ми пее рано на сабајле
# Писмо дојде од Солуна града
# По друм одам мајче
# Подигни си, бре невесте дулачето
# Подранила Цена за вода студена
# Појде моме на вода
# Поминаа луди млади години
# Развила гора зелена
# Разграни гранка маслинка
# Рајна на пенџере седеше
# Рајна на порти стоеше
# Распукала Шар Планина
# Са ноќ ми билбил препеа
# Саде ти се чудам, Цвето
# Само ме гледаш, очи ми пиеш
# Свалил се млад Димитар од Разловци
# Се заљубив во девојче убаво
# Се запали пиле Трено одајчето
# Секој што мине помине
# Сестра моли брата за вечера
# Си заљубив едно моме
# Сите девојчиња, мамо, се мажија
# Славеј пиле рано пее
# Слегло моме во градина
# Слушам кај шумат шумите
# Сношти минав покрај вази
# Сношти си мамо поминав
# Собрале ми се набрале
# Собрале ми се набрале нашите лични ергени
# Сокол ми лета високо
# Срце ме боли ќе умрам
# Стани запали Тинке борина
# Стани моме да заиграш
# Сторил ниет Зајко
# Сулиман ага
# Та ти ле се најде бабо
# Таму долу Криволачко, Црвени Брегови
# Те видов тебе и се заљубив
# Те сакам песно македонска
# Тешка беше нашата разделба
# Тинка иди од Битола
# Трба трби Гевгелија
# Тргнала ми мома Рума
# Три години либе ние се сакавме
# Туѓината пуста да остане
# Туљо бре, туљо Салтано
# У ливаду потке наше моме кротке
# Учи ме мајко карај ме
# Фанче ојде во Калишта
# Фатила зима
# Фато мори душманке
# Црна се чума зададе
# Црно му било пишано на Александро Турунџев
# Што имала к’смет Стамена
# Што се срамиш калеш Кирчо

# %%
len(songs)
# Out:
# 253

# %%
save_songs_to_json(songs, 'mkd_songs_3.json')

# %%
len(read_json_songs_to_list('mkd_songs_3.json'))
# Out:
# 253

# %%
songs[-1]
# Out:
# 'Што се срамиш калеш Кирчо\nШто се срамиш калеш Кирчо\nМене да погледаш\nМене да погледаш лудо\nВо црниве очи.\nНе се срамам лично моме\nТебе да погледам\nТук се плашам лично Севде\nТебе да заљубам.\nКој те тебе лично моме\nСал еднаш догледнал\nЉута рана лично Севде\nНа срце си ставил.\nЗемј мене калеш Кирчо\nЗа млада невеста\nДа не ставаш љута рана\nНа твоето срце.'
